# %%
import pandas as pd
import csv

df1 = pd.read_csv(r"https://raw.githubusercontent.com/chahna-ahuja/dh-g7-project/refs/heads/main/data/cleaned/final_drama_comedy.csv")
df2 = pd.read_csv(r"https://raw.githubusercontent.com/chahna-ahuja/dh-g7-project/refs/heads/main/data/cleaned/final_drama_play.csv")
df3 = pd.read_csv(r"https://raw.githubusercontent.com/chahna-ahuja/dh-g7-project/refs/heads/main/data/cleaned/final_drama_tragedy.csv")

merged = pd.concat([df1, df2, df3], ignore_index=True)

merged.to_csv("dh_group7_drama.csv", index=False)
